# %%
# Class 0

import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
#>>> image = mpimg.imread("chelsea-the-cat.png")
#>>> plt.imshow(image)
#>>> plt.show()

# %%
imglist = [2]
for i in imglist:
    num = str(i)
    imgname = 'Class/1/IMD00'+num+'/IMD00'+num+'_Dermoscopic_Image/IMD00'+num+'.bmp'  
    maskname = 'Class/1/IMD00'+num+'/IMD00'+num+'_lesion/IMD00'+num+'_lesion.bmp'
    img = cv2.imread(imgname)
    msk = cv2.imread(maskname)
    #cv2.imshow('image',img)
    #cv2.waitKey(0)
    #cv2.destroyAllWindows()
    plt.imshow(img)
    plt.show()
    print(img.shape)
    print(msk.shape)
    print(max(msk.any))
    img3 = img*msk
    #plt.imshow(img3)
    #plt.show()
    #cv2.imshow('image',img3)
    #cv2.waitKey(0)
    #cv2.destroyAllWindows()
    #print(msk[2][2][2])
# Out:
# (572, 765, 3)
# (572, 765, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-322068319559> in <module>()
#      15     print(img.shape)
#      16     print(msk.shape)
# ---> 17     print(max(msk.any))
#      18     img3 = img*msk
#      19     #plt.imshow(img3)
#
# TypeError: 'builtin_function_or_method' object is not iterable
